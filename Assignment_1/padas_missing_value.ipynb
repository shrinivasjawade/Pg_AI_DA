# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
# 1. Write a Pandas program to detect missing values of a given DataFrame. Display True or False.
df.isnull()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %%
# 2. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.
df.apply(lambda x : x.isnull()).any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %%
df.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %%
# 3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.

df.isnull().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
# 4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.

df.fillna("Empty")
# Out:
#      ord_no  purch_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50  2012-10-05         3002      5002.0
# 1     Empty     270.65  2012-09-10         3001      5003.0
# 2   70002.0      65.26       Empty         3001      5001.0
# 3   70004.0     110.50  2012-08-17         3003       Empty
# 4     Empty     948.50  2012-09-10         3002      5002.0
# 5   70005.0    2400.60  2012-07-27         3001      5001.0
# 6     Empty    5760.00  2012-09-10         3001      5001.0
# 7   70010.0    1983.43  2012-10-10         3004       Empty
# 8   70003.0    2480.40  2012-10-10         3003      5003.0
# 9   70012.0     250.45  2012-06-27         3002      5002.0
# 10    Empty      75.29  2012-08-17         3001      5003.0
# 11  70013.0    3045.60  2012-04-25         3001       Empty

# %%
# 5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.

df.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
# Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.

df.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %%
# 7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.
df.loc[12]= np.nan

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05       3002.0       5002.0
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0          NaN
# 4       NaN     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0    1983.43  2012-10-10       3004.0          NaN
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN
# 12      NaN        NaN         NaN          NaN          NaN

# %%
df.dropna(axis =0, how='all')
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05       3002.0       5002.0
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0          NaN
# 4       NaN     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0    1983.43  2012-10-10       3004.0          NaN
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %%
# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.
df.loc[0] = np.nan
df.loc[6] = np.nan
df.loc[8] = np.nan

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0       NaN        NaN         NaN          NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0          NaN
# 4       NaN     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6       NaN        NaN         NaN          NaN          NaN
# 7   70010.0    1983.43  2012-10-10       3004.0          NaN
# 8       NaN        NaN         NaN          NaN          NaN
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN
# 12      NaN        NaN         NaN          NaN          NaN

# %%
df.dropna(axis=0, thresh=2)
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
# 9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.
df.dropna(subset = "purch_amt")
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
# 10. Write a Pandas program to keep the valid entries of a given DataFrame.
df.dropna(inplace=False)
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
# 11. Write a Pandas program to calculate the total number of missing values in a DataFrame.

df.isna().value_counts().sum()
# Out:
# 12

# %%
# 12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.
df['purch_amt'].fillna(df['purch_amt'].mean(), inplace=False)
# Out:
# 0      150.50
# 1      270.65
# 2       65.26
# 3      110.50
# 4      948.50
# 5     2400.60
# 6     5760.00
# 7     1983.43
# 8     2480.40
# 9      250.45
# 10      75.29
# 11    3045.60
# Name: purch_amt, dtype: float64

# %%
# 13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.

df['purch_amt'].fillna(method='pad', inplace=False)
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_15172\570950838.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['purch_amt'].fillna(method='pad', inplace=False)
# 0      150.50
# 1      270.65
# 2       65.26
# 3      110.50
# 4      948.50
# 5     2400.60
# 6     5760.00
# 7     1983.43
# 8     2480.40
# 9      250.45
# 10      75.29
# 11    3045.60
# Name: purch_amt, dtype: float64

# %%
# 14. Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.
df['purch_amt'].fillna(df['purch_amt'].mean(), inplace=False)
# Out:
# 0      150.50
# 1      270.65
# 2       65.26
# 3      110.50
# 4      948.50
# 5     2400.60
# 6     5760.00
# 7     1983.43
# 8     2480.40
# 9      250.45
# 10      75.29
# 11    3045.60
# Name: purch_amt, dtype: float64

# %%
# Write a Pandas program to interpolate the missing values using the Linear Interpolation method in a given DataFrame.

df['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True)

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
# Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.
print(" Number if missing value in 'ord_no columns")
df['ord_no'].isnull().sum()
# Out:
# 5

# %%
# 17. Write a Pandas program to count the missing values in a given DataFrame.
df.isna().sum()
# Out:
# ord_no         5
# purch_amt      1
# ord_date       2
# customer_id    1
# salesman_id    4
# dtype: int64

# %%
# 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.
df['ord_no'].isnull().to_numpy().nonzero()
# Out:
# (array([ 1,  4,  6, 10, 12], dtype=int64),)

# %%
# 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.

df.fillna(df.mode().iloc[0])
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05       3002.0       5002.0
# 1   70001.0     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26  2012-09-10       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0       5001.0
# 4   70001.0     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6   70001.0    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0    1983.43  2012-10-10       3004.0       5001.0
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10  70001.0      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0       5001.0
# 12  70001.0      65.26  2012-09-10       3001.0       5001.0

# %%
# 20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.

sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
# Out:
# <Axes: >
