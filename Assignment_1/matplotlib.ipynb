# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr  = np.arange(15)
plt.plot(arr)
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.show()

# %%
#Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title.
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr)
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.show()

# %%
'''Write a Python program to draw a line using given axis values taken from a
text file, with suitable label in the x axis, y axis and a title.
Test Data:
test.txt
1 2
2 4
3 1'''
# Out:
# 'Write a Python program to draw a line using given axis values taken from a\ntext file, with suitable label in the x axis, y axis and a title.\nTest Data:\ntest.txt\n1 2\n2 4\n3 1'

# %%
df  = pd.read_csv('test.txt', sep=" ", header=None)

# %%
df
# Out:
#    0  1
# 0  1  2
# 1  2  4
# 2  3  1

# %%
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(df[0], df[1])
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.show()

# %%
# Write a Python program to draw line charts of the financial data of Alphabet
#Inc. between October 3, 2016 to October 7, 2016.
#Sample Financial data (fdata.csv):

# %%
df  = pd.read_csv('fdata.csv')

# %%
df.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.plot(df)
plt.legend(df.columns)

# %%
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line.

arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr)
plt.plot(arr[::-1])
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.legend(["Line1", "Line2"])
plt.show()

# %%
#6. Write a Python program to plot two or more lines with legends, different widths and colors.
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr)
plt.plot(arr[::-1], linewidth = 5)
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.legend(["Line1", "Line2"])
plt.show()

# %%
#Write a Python program to plot two or more lines with different styles.
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr, linestyle = '--')
plt.plot(arr[::-1], linewidth = 5, linestyle = ':')
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.legend(["Line1", "Line2"])
plt.show()

# %%
# Write a Python program to plot two or more lines and set the line markers.
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr, linestyle = '--')
plt.plot(arr[::-1], linewidth = 5, linestyle = ':', marker = 'o', markersize=9, markerfacecolor="blue")
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.legend(["Line1", "Line2"])
plt.show()

# %%
# Write a Python program to display the current axis limits values and set new axis values.
arr  = [0, 2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr)
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.xlim(0, 12)
plt.ylim(0, 12)
plt.show()

# %%
# Write a Python program to plot quantities which have an x and y position.
arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.scatter(arr, arr[::-1])
#plt.scatter(, linewidth = 5, linestyle = ':',' marker = 'o, markersize=9, markerfacecolor="blue")
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.show()

# %%
# Write a Python program to plot several lines with different format styles in one command using arrays.

arr  = [2,3,4,5,6,5,4,3,2,1,0]
plt.plot(arr, linestyle = '--')
plt.plot(arr[::-1], linewidth = 5, linestyle = ':')
plt.xlabel(" X-axis")
plt.ylabel('y-axis')
plt.title('Draw line')
plt.legend(["Line1", "Line2"])
plt.show()

# %%
# Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.
df = pd.read_csv('dateData.csv')

# %%
df
# Out:
#        Date       Close
# 0  03-10-16  772.559998
# 1  04-10-16  776.429993
# 2  05-10-16  776.469971
# 3  06-10-16  776.859985
# 4  07-10-16  775.080017

# %%
plt.plot(df['Date'], df['Close'],  marker = 'o', linestyle='--')

# %%
# Write a Python program to display the grid and draw line charts of the
#closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#Customized the grid lines with linestyle -, width .5. and color blue.


plt.plot(df['Date'], df['Close'],  marker = 'o', linestyle='--', linewidth = .5, color = 'blue')
plt.xlabel("Date")
plt.ylabel('Closing Value')
plt.title(" Value of alpha Inc")
plt.grid(linestyle='--', linewidth = .5)

# %%
#Write a Python program to display the grid and draw line charts of the
#closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#Customized the grid lines with rendering with a larger grid (major grid) and a
#smaller grid (minor grid).Turn on the grid but turn off ticks.

plt.plot(df['Date'], df['Close'],  marker = 'o', linestyle='--', linewidth = .5, color = 'blue')
plt.xlabel("Date")
plt.ylabel('Closing Value')
plt.title(" Value of alpha Inc")
plt.grid(linestyle='--', linewidth = .5)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')

plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# Turn off the display of all ticks.
plt.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks

plt.show()

# %%
#Write a Python program to create multiple plots.

fig = plt.figure()
plt.subplot(2, 1, 1)
plt.subplot(2, 3, 4)
plt.subplot(2, 3, 5)
plt.subplot(2, 3, 6)

fig.subplots_adjust(bottom=0.020, left=0.020, top = 0.900, right=0.900, wspace=0.5,
    hspace=0.4,)

plt.show()
